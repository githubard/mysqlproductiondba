# %%
Manually download RPMs and locally install 
=================================================================

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
[root@mysqlserver Downloads]# ls -rtl
total 70820
-rwxr-xr-x. 1 mysqluser mysqluser    15364 May 13 14:03 mysql84-community-release-el8-1.noarch.rpm
-rwxr-xr-x. 1 mysqluser mysqluser 55296452 May 14 01:18 mysql-community-server-8.0.20-1.el8.x86_64.rpm
-rwxr-xr-x. 1 mysqluser mysqluser 12833868 May 14 01:19 mysql-community-client-8.0.20-1.el8.x86_64.rpm
-rwxr-xr-x. 1 mysqluser mysqluser  1519360 May 14 01:19 mysql-community-libs-8.0.20-1.el8.x86_64.rpm
-rwxr-xr-x. 1 mysqluser mysqluser  2214428 May 14 01:25 mysql-community-devel-8.0.20-1.el8.x86_64.rpm
-rwxr-xr-x. 1 mysqluser mysqluser   627352 May 14 01:25 mysql-community-common-8.0.20-1.el8.x86_64.rpm
[root@mysqlserver Downloads]# 


[root@mysqlserver Downloads]# yum localinstall mysql84-community-release-el8-1.noarch.rpm
Last metadata expiration check: 1:41:23 ago on Mon 13 May 2024 11:45:24 PM IST.
Dependencies resolved.
Installed:
  mysql84-community-release-el8-1.noarch                                                                                           

Complete!
[root@mysqlserver Downloads]# 


[root@mysqlserver Downloads]# yum localinstall mysql-community-*.rpm
Last metadata expiration check: 1:35:48 ago on Mon 13 May 2024 11:52:45 PM IST.
Dependencies resolved.

Installed:
  keyutils-libs-devel-1.5.10-9.el8.x86_64   krb5-devel-1.18.2-14.el8.x86_64           
   libcom_err-devel-1.45.6-2.el8.x86_64      
  libkadm5-1.18.2-14.el8.x86_64             libselinux-devel-2.9-5.el8.x86_64          
  libsepol-devel-2.9-3.el8.x86_64           
  libverto-devel-0.3.0-5.el8.x86_64         mysql-community-client-8.0.20-1.el8.x86_64 
  mysql-community-common-8.0.20-1.el8.x86_64
  mysql-community-devel-8.0.20-1.el8.x86_64 mysql-community-libs-8.0.20-1.el8.x86_64   
  mysql-community-server-8.0.20-1.el8.x86_64
  openssl-devel-1:1.1.1k-4.el8.x86_64       pcre2-devel-10.32-2.el8.x86_64            
   pcre2-utf16-10.32-2.el8.x86_64            
  pcre2-utf32-10.32-2.el8.x86_64            zlib-devel-1.2.11-17.el8.x86_64           

Complete!
[root@mysqlserver Downloads]# 


[root@mysqlserver Downloads]# rpm -qa | grep mysql
mysql-community-client-8.0.20-1.el8.x86_64
mysql84-community-release-el8-1.noarch
mysql-community-devel-8.0.20-1.el8.x86_64
mysql-community-common-8.0.20-1.el8.x86_64
mysql-community-server-8.0.20-1.el8.x86_64
mysql-community-libs-8.0.20-1.el8.x86_64
[root@mysqlserver Downloads]# 


[root@mysqlserver Downloads]# systemctl start mysqld
[root@mysqlserver Downloads]# 
[root@mysqlserver Downloads]# systemctl status mysqld
● mysqld.service - MySQL Server
   Loaded: loaded (/usr/lib/systemd/system/mysqld.service; enabled; vendor preset: disabled)
   Active: active (running) since Tue 2024-05-14 01:31:03 IST; 16s ago
