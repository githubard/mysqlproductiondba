# %%
Install Percona Tool Kit 
==================================================

[root@bospprod01 Downloads]# 
wget "https://downloads.percona.com/downloads/percona-toolkit/3.4.0/binary/redhat/7/x86_64/percona-toolkit-3.4.0-3.el7.
x86_64.rpm"


[root@bospprod01 Downloads]# yum localinstall percona-toolkit-3.4.0-3.el7.x86_64.rpm

Installed:
  percona-toolkit.x86_64 0:3.4.0-3.el7      


[root@bospprod01 Downloads]# rpm -qa | grep percona
percona-toolkit-3.4.0-3.el7.x86_64
[root@bospprod01 Downloads]# 

[root@bospprod01 Downloads]# rpm -ql percona-toolkit-3.4.0-3.el7.x86_64
/usr/bin/pt-align
/usr/bin/pt-archiver
/usr/bin/pt-config-diff
/usr/bin/pt-deadlock-logger
/usr/bin/pt-diskstats
/usr/bin/pt-duplicate-key-checker

# %%
List all the features of percona toolkit 
=============================================================

[root@bospprod01 Downloads]# ls -rtl /usr/bin/pt-*
-rwxr-xr-x. 1 root root   334330 Jul  7  2022 /usr/bin/pt-upgrade
-rwxr-xr-x. 1 root root   248920 Jul  7  2022 /usr/bin/pt-table-usage
-rwxr-xr-x. 1 root root   406557 Jul  7  2022 /usr/bin/pt-table-sync
-rwxr-xr-x. 1 root root   132695 Jul  7  2022 /usr/bin/pt-slave-find
-rwxr-xr-x. 1 root root   437790 Jul  7  2022 /usr/bin/pt-online-schema-change
-rwxr-xr-x. 1 root root   108027 Jul  7  2022 /usr/bin/pt-mysql-summary
-rwxr-xr-x. 1 root root   257791 Jul  7  2022 /usr/bin/pt-kill
-rwxr-xr-x. 1 root root    32538 Jul  7  2022 /usr/bin/pt-ioprofile
-rwxr-xr-x. 1 root root    67933 Jul  7  2022 /usr/bin/pt-fingerprint
-rwxr-xr-x. 1 root root   152804 Jul  7  2022 /usr/bin/pt-find
-rwxr-xr-x. 1 root root    50280 Jul  7  2022 /usr/bin/pt-fifo-split
-rwxr-xr-x. 1 root root   169033 Jul  7  2022 /usr/bin/pt-deadlock-logger
-rwxr-xr-x. 1 root root   272303 Jul  7  2022 /usr/bin/pt-archiver
-rwxr-xr-x. 1 root root   103579 Jul  7  2022 /usr/bin/pt-visual-explain
-rwxr-xr-x. 1 root root   179466 Jul  7  2022 /usr/bin/pt-variable-advisor
-rwxr-xr-x. 1 root root   462067 Jul  7  2022 /usr/bin/pt-table-checksum
-rwxr-xr-x. 1 root root    90906 Jul  7  2022 /usr/bin/pt-summary
-rwxr-xr-x. 1 root root    77765 Jul  7  2022 /usr/bin/pt-stalk
-rwxr-xr-x. 1 root root   186209 Jul  7  2022 /usr/bin/pt-slave-restart
-rwxr-xr-x. 1 root root   147925 Jul  7  2022 /usr/bin/pt-slave-delay
-rwxr-xr-x. 1 root root    37916 Jul  7  2022 /usr/bin/pt-sift
-rwxr-xr-x. 1 root root    79291 Jul  7  2022 /usr/bin/pt-show-grants
-rwxr-xr-x. 1 root root   529921 Jul  7  2022 /usr/bin/pt-query-digest
-rwxr-xr-x. 1 root root    24731 Jul  7  2022 /usr/bin/pt-pmp
-rwxr-xr-x. 1 root root    22047 Jul  7  2022 /usr/bin/pt-mext
-rwxr-xr-x. 1 root root   229280 Jul  7  2022 /usr/bin/pt-index-usage
-rwxr-xr-x. 1 root root   225748 Jul  7  2022 /usr/bin/pt-heartbeat
-rwxr-xr-x. 1 root root   135950 Jul  7  2022 /usr/bin/pt-fk-error-logger
-rwxr-xr-x. 1 root root   172080 Jul  7  2022 /usr/bin/pt-duplicate-key-checker
-rwxr-xr-x. 1 root root   166584 Jul  7  2022 /usr/bin/pt-diskstats
-rwxr-xr-x. 1 root root   171720 Jul  7  2022 /usr/bin/pt-config-diff
-rwxr-xr-x. 1 root root    41859 Jul  7  2022 /usr/bin/pt-align
-rwxr-xr-x. 1 root root  4116248 Jul  7  2022 /usr/bin/pt-secure-collect
-rwxr-xr-x. 1 root root  6200024 Jul  7  2022 /usr/bin/pt-pg-summary
-rwxr-xr-x. 1 root root 11252024 Jul  7  2022 /usr/bin/pt-mongodb-summary
-rwxr-xr-x. 1 root root 11045944 Jul  7  2022 /usr/bin/pt-mongodb-query-digest
-rwxr-xr-x. 1 root root 11101880 Jul  7  2022 /usr/bin/pt-mongodb-index-check
-rwxr-xr-x. 1 root root 12925368 Jul  7  2022 /usr/bin/pt-k8s-debug-collector

# %%
Download a large dataset ( airport-db ) for testing
==========================================================

[root@bospprod01 Downloads]# wget "https://downloads.mysql.com/docs/airport-db.tar.gz"

[root@bospprod01 Downloads]# gunzip airport-db.tar.gz

[root@bospprod01 Downloads]# ls -rtl  | grep drw | grep airport
drwxr-xr-x. 2  500  500      8192 Apr 30 18:05 airport-db


[root@bospprod01 Downloads] wget "https://downloads.mysql.com/archives/get/p/43/file/mysql-shell-8.0.30-1.el7.x86_64.rpm"

[root@bospprod01 Downloads]# yum localinstall mysql-shell-8.0.30-1.el7.x86_64.rpm

[root@bospprod01 Downloads]# which mysqlsh
/bin/mysqlsh
[root@bospprod01 Downloads]# 


[root@bospprod01 airport-db]# cat README.txt 

This directory contains the files for setting up the airportdb sample 
database on a MySQL DB System on Oracle Cloud Infrastructure (OCI).

Download an airportdb archive file to the Compute instance and unpack it.

Load airportdb on the MySQL DB System using the MySQL Shell Dump Loading 
Utility. On the Compute instance that you use to connect to the DB System, 
start MySQL Shell and run the following command:

MySQL>JS> util.loadDump("airport-db", {threads: 16, deferTableIndexes: "all", 
          ignoreVersion: true})


[root@bospprod01 Downloads]# mysqlsh
MySQL Shell 8.0.30

MySQL  JS > \connect --mysql root@localhost
Creating a Classic session to 'root@localhost'
Fetching schema names for autocompletion... Press ^C to stop.
Your MySQL connection id is 13
Server version: 8.0.30 MySQL Community Server - GPL

 MySQL  localhost  JS > util.loadDump("airport-db", {threads: 16, deferTableIndexes: "all",ignoreVersion: true})
ERROR: The 'local_infile' global system variable must be set to ON in the target server, after the server is 
verified to be trusted.

mysql> set global local_infile = ON;
Query OK, 0 rows affected (0.00 sec)


MySQL  localhost  JS > util.loadDump("airport-db", {threads: 16, deferTableIndexes: "all",ignoreVersion: true})
Loading DDL and Data from 'airport-db' using 16 threads.
Opening dump...
NOTE: Dump format has version 1.0.2 and was created by an older version of MySQL Shell. If you experience problems loading it, please recreate the dump using the current version of MySQL Shell and try again.
Target is MySQL 8.0.30. Dump was produced from MySQL 8.0.26-cloud
Scanning metadata - done       
Checking for pre-existing objects...
Executing common preamble SQL
Executing DDL - done       
Executing view DDL - done       
Starting data load
8 thds loading / 100% (2.03 GB / 2.03 GB), 3.97 MB/s, 12 / 14 tables done                  
Executing common postamble SQL                                           
Recreating indexes - done         
37 chunks (59.50M rows, 2.03 GB) for 14 tables in 1 schemas were loaded in 15 min 39 sec (avg throughput 5.83 MB/s)
0 warnings were reported during the load.                                
 MySQL  localhost  JS >

# %%
ENABLE SLOW QUERY LOG 
======================================

mysql> show variables like '%slow%';
+-----------------------------+------------------------------------+
| Variable_name               | Value                              |
+-----------------------------+------------------------------------+
| log_slow_admin_statements   | OFF                                |
| log_slow_extra              | OFF                                |
| log_slow_replica_statements | OFF                                |
| log_slow_slave_statements   | OFF                                |
| slow_launch_time            | 2                                  |
| slow_query_log              | OFF                                |
| slow_query_log_file         | /var/lib/mysql/bospprod01-slow.log |
+-----------------------------+------------------------------------+


mysql> show variables like '%query_time%';
+-----------------+-----------+
| Variable_name   | Value     |
+-----------------+-----------+
| long_query_time | 10.000000 |
+-----------------+-----------+
1 row in set (0.00 sec)


[root@bospprod01 ~]# vi /etc/my.cnf
[root@bospprod01 ~]# 
[root@bospprod01 ~]# cat /etc/my.cnf | grep slow
slow_query_log = ON
[root@bospprod01 ~]# systemctl restart mysqld
[root@bospprod01 ~]# 

mysql> show variables like '%slow_query_log%';
+---------------------+------------------------------------+
| Variable_name       | Value                              |
+---------------------+------------------------------------+
| slow_query_log      | ON                                 |
| slow_query_log_file | /var/lib/mysql/bospprod01-slow.log |
+---------------------+------------------------------------+
2 rows in set (0.00 sec)

# %%
RUN SOME LONG QUERIES IN THE DATABASE 
======================================================

mysql> select count(*) from airline;
+----------+
| count(*) |
+----------+
|      113 |
+----------+
1 row in set (0.03 sec)

mysql> select count(*) from booking;
+----------+
| count(*) |
+----------+
| 54304619 |
+----------+
1 row in set (26.46 sec)

mysql> select * from booking where flight_id > 100;
mysql: Out of memory (Needed 1570824224 bytes)
ERROR 2008 (HY000): MySQL client ran out of memory


mysql> select pa.firstname , bo.booking_id , bo.flight_id , bo.price
    -> from passenger pa inner join booking bo on pa.passenger_id = bo.passenger_id
    -> where pa.firstname like '%ma%'
    -> order by pa.firstname;

+----------------------------------+------------+-----------+--------+
3691228 rows in set (9 min 37.67 sec)


mysql> show engine innodb status \G

--------------
ROW OPERATIONS
--------------
0 queries inside InnoDB, 0 queries in queue
1 read views open inside InnoDB
Process ID=3313, Main thread ID=139776870655744 , state=sleeping


top - 02:00:53 up 35 min,  3 users,  load average: 1.67, 1.17, 0.74
Tasks: 211 total,   1 running, 210 sleeping,   0 stopped,   0 zombie
# %Cpu(s):  5.7 us, 29.4 sy,  0.0 ni, 39.4 id, 18.9 wa,  0.0 hi,  6.6 si,  0.0 st
KiB Mem :  3861292 total,   115804 free,  1954888 used,  1790600 buff/cache
KiB Swap:  3145724 total,  2329308 free,   816416 used.  1626204 avail Mem 

   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND                                                                                  
  3313 mysql     20   0 2815444   1.1g      0 S  60.6 28.6   6:06.90 mysqld                                                                                   
    35 root      20   0       0      0      0 S   6.1  0.0   0:36.05 kswapd0                                                                                  
  2462 mysqlus+  20   0 3612656 178520  58716 S   5.6  4.6   1:29.89 gnome-shell                                                                              



mysql> select pa.firstname , bo.booking_id , bo.flight_id , bo.price from passenger pa inner join booking bo 
on pa.passenger_id = bo.passenger_id where pa.firstname like '%mar%' order by pa.firstname;

1779913 rows in set (4 min 18.72 sec)

mysql> select pa.firstname , bo.booking_id , bo.flight_id , bo.price from passenger pa inner join booking 
bo on pa.passenger_id = bo.passenger_id where pa.firstname like '%mart%' order by pa.firstname;

253661 rows in set (34.73 sec)

mysql> select pa.firstname , bo.booking_id , bo.flight_id , bo.price from passenger pa inner join 
booking bo on pa.passenger_id = bo.passenger_id where pa.firstname like '%mar%' order by pa.firstname;



[root@bospprod01 Downloads]# pt-mysql-summary 

# Percona Toolkit MySQL Summary Report #######################
              System time | 2024-05-28 06:16:41 UTC (local TZ: EDT -0400)
# Instances ##################################################
  Port  Data Directory             Nice OOM Socket
  ===== ========================== ==== === ======
# Report On Port 3306 ########################################
                     User | root@localhost
                     Time | 2024-05-28 02:16:40 (EDT)
                 Hostname | bospprod01
                  Version | 8.0.30 MySQL Community Server - GPL
                 Built On | Linux x86_64
                  Started | 2024-05-28 01:40 (up 0+00:36:20)
                Databases | 5
                  Datadir | /var/lib/mysql/
                Processes | 2 connected, 3 running
              Replication | Is not a slave, has 0 slaves connected
                  Pidfile | /var/run/mysqld/mysqld.pid (exists)

# InnoDB #####################################################
                  Version | 8.0.30
         Buffer Pool Size | 1.0G
         Buffer Pool Fill | 100%
        Buffer Pool Dirty | 0%
           File Per Table | ON
                Page Size | 16k
            Log File Size | 2 * 48.0M = 96.0M
          Log Buffer Size | 16M
             Flush Method | fsync
      Flush Log At Commit | 1

# %%
VIEW SLOW QUERY LOGS WITH MYSQLDUMPSLOW
=======================================================

[root@bospprod01 Downloads]# ls -rtl /var/lib/mysql/*slow*
-rw-r-----. 1 mysql mysql 2236 May 28 02:19 /var/lib/mysql/bospprod01-slow.log
[root@bospprod01 Downloads]# 


[root@bospprod01 Downloads]# mysqldumpslow /var/lib/mysql/bospprod01-slow.log

Reading mysql slow query log from /var/lib/mysql/bospprod01-slow.log

Count: 1  Time=577.67s (577s)  Lock=0.00s (0s)  Rows=3691228.0 (3691228), root[root]@localhost
  select pa.firstname , bo.booking_id , bo.flight_id , bo.price
  from passenger pa inner join booking bo on pa.passenger_id = bo.passenger_id
  where pa.firstname like 'S'
  order by pa.firstname

Count: 3  Time=188.03s (564s)  Lock=0.00s (0s)  Rows=1271162.3 (3813487), root[root]@localhost
  select pa.firstname , bo.booking_id , bo.flight_id , bo.price from passenger pa inner join booking bo on 
  pa.passenger_id = bo.passenger_id where pa.firstname like 'S' order by pa.firstname

Count: 1  Time=88.34s (88s)  Lock=0.00s (0s)  Rows=29606838.0 (29606838), root[root]@localhost
  select * from booking where flight_id > N

Count: 1  Time=26.46s (26s)  Lock=0.00s (0s)  Rows=1.0 (1), root[root]@localhost
  select count(*) from booking

# %%
ANALYSE SLOW QUERY LOGS THROUGH PERCONA TOOL KIT QUERY DIGEST
====================================================================

NAME
    pt-query-digest - Analyze MySQL queries from logs, processlist, and
    tcpdump.

SYNOPSIS
    Usage: pt-query-digest [OPTIONS] [FILES] [DSN]

    pt-query-digest analyzes MySQL queries from slow, general, and binary log
    files. It can also analyze queries from "SHOW PROCESSLIST" and MySQL
    protocol data from tcpdump. By default, queries are grouped by fingerprint



ANALYSE SLOW QUERY LOG 
========================================


[root@bospprod01 Downloads]# pt-query-digest /var/lib/mysql/bospprod01-slow.log

# 100ms user time, 100ms system time, 26.78M rss, 221.29M vsz

# Current date: Tue May 28 02:36:41 2024
# Hostname: bospprod01
# Files: /var/lib/mysql/bospprod01-slow.log

# Overall: 6 total, 3 unique, 0.00 QPS, 0.58x concurrency ________________
# Time range: 2024-05-28T05:43:21 to 2024-05-28T06:19:17
# Attribute          total     min     max     avg     95%  stddev  median
# ============     ======= ======= ======= ======= ======= ======= =======
# Exec time          1257s     26s    578s    209s    564s    187s    258s
# Lock time           49us     3us    14us     8us    13us     4us    12us
# Rows sent         35.39M       1  28.24M   5.90M  27.20M   9.68M   1.69M
# Rows examine      35.54M       0  28.24M   5.92M  27.20M   9.67M   1.69M
# Query size           839      28     193  139.83  192.76   71.36  183.58

# Profile
# Rank Query ID                            Response time   Calls R/Call   
# ==== =================================== =============== ===== ======== 
#    1 0x433FACBF4CC23284475392B4DE1D0C7A  1141.7535 90.9%     4 285.4384 12... SELECT passenger booking
#    2 0x7ADD0528A0F3EAEFADB763AE786E8D8E    88.3395  7.0%     1  88.3395  0.00 SELECT booking
# MISC 0xMISC                                26.4562  2.1%     1  26.4562   0.0 <1 ITEMS>

# Query 1: 0.00 QPS, 1.16x concurrency, ID 0x433FACBF4CC23284475392B4DE1D0C7A at byte 660
# This item is included in the report because it matches --limit.
# Scores: V/M = 124.71
# Time range: 2024-05-28T06:02:55 to 2024-05-28T06:19:17
# Attribute    pct   total     min     max     avg     95%  stddev  median
# ============ === ======= ======= ======= ======= ======= ======= =======
# Count         66       4
# Exec time     90   1142s     35s    578s    285s    564s    189s    258s
# Lock time     87    43us     4us    14us    10us    13us     3us    13us
# Rows sent     20   7.16M 247.72k   3.52M   1.79M   3.50M   1.16M   1.69M
# Rows examine  20   7.30M 283.13k   3.56M   1.82M   3.50M   1.15M   1.69M
# Query size    91     768     191     193     192  192.76       1  183.58
# String:
# Databases    airportdb
# Hosts        localhost
# Users        root
# Query_time distribution
#   1us
#  10us
# 100us
#   1ms
#  10ms
# 100ms
#    1s
#  10s+  ################################################################
# Tables
#    SHOW TABLE STATUS FROM `airportdb` LIKE 'passenger'\G
#    SHOW CREATE TABLE `airportdb`.`passenger`\G
#    SHOW TABLE STATUS FROM `airportdb` LIKE 'booking'\G
#    SHOW CREATE TABLE `airportdb`.`booking`\G
# EXPLAIN /*!50100 PARTITIONS*/
select pa.firstname , bo.booking_id , bo.flight_id , bo.price
from passenger pa inner join booking bo on pa.passenger_id = bo.passenger_id
where pa.firstname like '%ma%'
order by pa.firstname\G

# Query 2: 0 QPS, 0x concurrency, ID 0x7ADD0528A0F3EAEFADB763AE786E8D8E at byte 413
# This item is included in the report because it matches --limit.
# Scores: V/M = 0.00
# Time range: all events occurred at 2024-05-28T05:46:49
# Attribute    pct   total     min     max     avg     95%  stddev  median
# ============ === ======= ======= ======= ======= ======= ======= =======
# Count         16       1
# Exec time      7     88s     88s     88s     88s     88s       0     88s
# Lock time      6     3us     3us     3us     3us     3us       0     3us
# Rows sent     79  28.24M  28.24M  28.24M  28.24M  28.24M       0  28.24M
# Rows examine  79  28.24M  28.24M  28.24M  28.24M  28.24M       0  28.24M
# Query size     5      43      43      43      43      43       0      43
# String:
# Databases    airportdb
# Hosts        localhost
# Users        root
# Query_time distribution
#   1us
#  10us
# 100us
#   1ms
#  10ms
# 100ms
#    1s
#  10s+  ################################################################
# Tables
#    SHOW TABLE STATUS FROM `airportdb` LIKE 'booking'\G
#    SHOW CREATE TABLE `airportdb`.`booking`\G
# EXPLAIN /*!50100 PARTITIONS*/
select * from booking where flight_id > 100\G
[root@bospprod01 Downloads]# 



ANALYSE SLOW QUERY LOG WITH EXPLAIN
=======================================================

[root@bospprod01 Downloads]# pt-query-digest --explain=localhost  /var/lib/mysql/bospprod01-slow.log
DBI connect(';host=localhost;mysql_read_default_group=client','',...) failed: Authentication plugin 
'caching_sha2_password' cannot be loaded: /usr/lib64/mysql/plugin/caching_sha2_password.so: cannot 
open shared object file: No such file or directory at /bin/pt-query-digest line 1001.
[root@bospprod01 Downloads]# 

mysql> alter user 'root'@'localhost' identified with mysql_native_password;
Query OK, 0 rows affected (0.00 sec)


[root@bospprod01 Downloads]# pt-query-digest --explain=localhost  /var/lib/mysql/bospprod01-slow.log

# %%
ANALYSE PROCESSLIST QUERIES WITH PERCONA TOOL KIT QUERY DIGEST
===========================================================================

[root@bospprod01 Downloads]# pt-query-digest --run-time="1m" --iterations=5 --processlist localhost

Reading from STDIN ...

# No events processed.

# No events processed.

# 840ms user time, 230ms system time, 25.14M rss, 236.63M vsz
# Current date: Tue May 28 04:19:17 2024
# Hostname: bospprod01
# Files: STDIN
# Overall: 1 total, 1 unique, 0 QPS, 0x concurrency ______________________
# Time range: all events occurred at 2024-05-28T04:16:17
# Attribute          total     min     max     avg     95%  stddev  median
# ============     ======= ======= ======= ======= ======= ======= =======
# Exec time           130s    130s    130s    130s    130s       0    130s
# Lock time              0       0       0       0       0       0       0
# Query size           193     193     193     193     193       0     193
# id                    19      19      19      19      19       0      19

# Profile
# Rank Query ID                            Response time   Calls R/Call   
# ==== =================================== =============== ===== ======== 
#    1 0x433FACBF4CC23284475392B4DE1D0C7A  129.9518 100.0%     1 129.9518  0.00 SELECT passenger booking

# Query 1: 0 QPS, 0x concurrency, ID 0x433FACBF4CC23284475392B4DE1D0C7A at byte 0
# This item is included in the report because it matches --limit.
# Scores: V/M = 0.00
# Time range: all events occurred at 2024-05-28T04:16:17
# Attribute    pct   total     min     max     avg     95%  stddev  median
# ============ === ======= ======= ======= ======= ======= ======= =======
# Count        100       1
# Exec time    100    130s    130s    130s    130s    130s       0    130s
# Lock time      0       0       0       0       0       0       0       0
# Query size   100     193     193     193     193     193       0     193
# id           100      19      19      19      19      19       0      19
# String:
# Databases    airportdb
# Hosts        localhost
# Users        root
# Query_time distribution
#   1us
#  10us
# 100us
#   1ms
#  10ms
# 100ms
#    1s
#  10s+  ################################################################
# Tables
#    SHOW TABLE STATUS FROM `airportdb` LIKE 'passenger'\G
#    SHOW CREATE TABLE `airportdb`.`passenger`\G
#    SHOW TABLE STATUS FROM `airportdb` LIKE 'booking'\G
#    SHOW CREATE TABLE `airportdb`.`booking`\G
# EXPLAIN /*!50100 PARTITIONS*/
select pa.firstname , bo.booking_id , bo.flight_id , bo.price from passenger pa inner join booking bo 
on pa.passenger_id = bo.passenger_id where pa.firstname like '%mar%' order by pa.firstname\G

# No events processed.

# 1.2s user time, 310ms system time, 25.19M rss, 236.76M vsz
# Current date: Tue May 28 04:21:17 2024
# Hostname: bospprod01
# Files: STDIN
# Overall: 1 total, 1 unique, 0 QPS, 0x concurrency ______________________
# Time range: all events occurred at 2024-05-28T04:18:27
# Attribute          total     min     max     avg     95%  stddev  median
# ============     ======= ======= ======= ======= ======= ======= =======
# Exec time           220s    220s    220s    220s    220s       0    220s
# Lock time              0       0       0       0       0       0       0
# Query size           193     193     193     193     193       0     193
# id                    19      19      19      19      19       0      19

# Profile
# Rank Query ID                            Response time   Calls R/Call   
# ==== =================================== =============== ===== ======== 
#    1 0x433FACBF4CC23284475392B4DE1D0C7A  220.0000 100.0%     1 220.0000  0.00 SELECT passenger booking

# Query 1: 0 QPS, 0x concurrency, ID 0x433FACBF4CC23284475392B4DE1D0C7A at byte 0
# This item is included in the report because it matches --limit.
# Scores: V/M = 0.00
# Time range: all events occurred at 2024-05-28T04:18:27
# Attribute    pct   total     min     max     avg     95%  stddev  median
# ============ === ======= ======= ======= ======= ======= ======= =======
# Count        100       1
# Exec time    100    220s    220s    220s    220s    220s       0    220s
# Lock time      0       0       0       0       0       0       0       0
# Query size   100     193     193     193     193     193       0     193
# id           100      19      19      19      19      19       0      19
# String:
# Databases    airportdb
# Hosts        localhost
# Users        root
# Query_time distribution
#   1us
#  10us
# 100us
#   1ms
#  10ms
# 100ms
#    1s
#  10s+  ################################################################
# Tables
#    SHOW TABLE STATUS FROM `airportdb` LIKE 'passenger'\G
#    SHOW CREATE TABLE `airportdb`.`passenger`\G
#    SHOW TABLE STATUS FROM `airportdb` LIKE 'booking'\G
#    SHOW CREATE TABLE `airportdb`.`booking`\G
# EXPLAIN /*!50100 PARTITIONS*/
select pa.firstname , bo.booking_id , bo.flight_id , bo.price from passenger pa inner join booking bo  on 
pa.passenger_id = bo.passenger_id where pa.firstname like '%mar%' order by pa.firstname\G
[root@bospprod01 Downloads]#

# %%
ANALYSE BIN LOGS THROUGH PERCONA TOOL KIT QUERY DIGEST
====================================================================

mysql> flush logs;

mysql> show master status;
+---------------+----------+--------------+------------------+-------------------+
| File          | Position | Binlog_Do_DB | Binlog_Ignore_DB | Executed_Gtid_Set |
+---------------+----------+--------------+------------------+-------------------+
| binlog.000006 |      157 |              |                  |                   |
+---------------+----------+--------------+------------------+-------------------+
1 row in set (0.01 sec)

mysql> select pa.firstname , bo.booking_id , bo.flight_id , bo.price from passenger pa inner join booking  bo on 
pa.passenger_id = bo.passenger_id where pa.firstname like '%mart%' order by pa.firstname;

253661 rows in set (57.27 sec)

[root@bospprod01 Downloads]# ls -rtl /var/lib/mysql/binlog.000006
-rw-r-----. 1 mysql mysql 157 May 28 03:41 /var/lib/mysql/binlog.000006
[root@bospprod01 Downloads]# 


[root@bospprod01 Downloads]# mysqlbinlog /var/lib/mysql/binlog.000006 > binlog6.sql
[root@bospprod01 Downloads]# 

[root@bospprod01 Downloads]# pt-query-digest binlog6.sql

# 70ms user time, 150ms system time, 26.59M rss, 221.15M vsz
# Current date: Tue May 28 05:51:38 2024
# Hostname: bospprod01
# Files: binlog6.sql
# Overall: 0 total, 9 unique, 0 QPS, 0x concurrency ______________________
# Attribute          total     min     max     avg     95%  stddev  median
# ============     ======= ======= ======= ======= ======= ======= =======
# Query size        28.09k      11   5.28k  422.96  964.41   1.06k   59.77

# Profile
# Rank   Query ID                            Response time Calls  R/Call V
# ====== =================================== ====== ====== ====== ===== ==
[root@bospprod01 Downloads]# 
[root@bospprod01 Downloads]#

# %%
OTHER FEATURES OF PERCONA TOOL KIT
=========================================================


[root@bospprod01 Downloads]# pt-table-usage /var/lib/mysql/bospprod01-slow.log

Query_id: 0x34A599AFD8FEA756.1
SELECT airportdb.booking

Query_id: 0xADB763AE786E8D8E.1
SELECT booking
WHERE booking

Query_id: 0x475392B4DE1D0C7A.1
SELECT passenger
SELECT booking
JOIN passenger
JOIN booking
WHERE passenger


[root@bospprod01 Downloads]# pt-slave-find localhost

localhost
Version         8.0.30
Server ID       1
Uptime          02:52:24 (started 2024-05-28T03:29:29)
Replication     Is not a slave, has 0 slaves connected, is not read_only
Filters         
Binary logging  ROW
Slave status    
Slave mode      STRICT
Auto-increment  increment 1, offset 1
InnoDB version  8.0.30
[root@bospprod01 Downloads]#
